# %% [markdown]
# <a href="https://colab.research.google.com/github/jgarvey928/LearningPython_6th_MarkLutz/blob/main/Daily_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
while i < 5:
  print(i)
  i+=2
# Out:
# 0
# 1
# 2
# 3
# 4
