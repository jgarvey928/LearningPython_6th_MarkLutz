# %% [markdown]
# <a href="https://colab.research.google.com/github/jgarvey928/LearningPython_6th_MarkLutz/blob/main/CH02_How_Python_Runs_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world')
print(2 ** 100)
# Out:
# hello world
# 1267650600228229401496703205376
