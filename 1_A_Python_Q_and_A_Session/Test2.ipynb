# %% [markdown]
# <a href="https://colab.research.google.com/github/jgarvey928/LearningPython_6th_MarkLutz/blob/main/1_A_Python_Q_and_A_Session/Test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
while i < 10:
    print("burp")
    i+=1
# Out:
# butts
# butts
# butts
# butts
# butts
