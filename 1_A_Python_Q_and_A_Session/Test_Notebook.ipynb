# %% [markdown]
# <a href="https://colab.research.google.com/github/jgarvey928/LearningPython_6th_MarkLutz/blob/main/1_A_Python_Q_and_A_Session/Test_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 0
while i < 5:
    print("testing")
    i+=1
# Out:
# testing
# testing
# testing
# testing
# testing

# %%
i = 0
while i < 10:
    print("fart")
    i+=1
# Out:
# fart
# fart
# fart
# fart
# fart
# fart
# fart
# fart
# fart
# fart
