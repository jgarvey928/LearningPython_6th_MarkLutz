# %%
i = 0
while i < 10:
    print("test")
    i+=1
# Out:
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test

# %%
i = 0
while i < 10:
    print("fart")
    i+=1
# Out:
# fart
# fart
# fart
# fart
# fart
# fart
# fart
# fart
# fart
# fart
